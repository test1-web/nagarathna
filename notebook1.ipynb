# %%
import sklearn, imblearn
print("scikit-learn:", sklearn.__version__)
print("imbalanced-learn:", imblearn.__version__)
# Out:
# scikit-learn: 1.7.2
# imbalanced-learn: 0.14.0

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100], dtype=int64))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
X_train.shape
# Out:
# (700, 10)

# %%
X_test.shape
# Out:
# (300, 10)

# %%
log_reg = LogisticRegression(max_iter=1000,C=1, solver='liblinear')
log_reg.fit(X_train, y_train)
y_pred_log_reg = log_reg.predict(X_test)
print(classification_report(y_test, y_pred_log_reg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       270
#            1       0.45      0.87      0.59        30
#
#     accuracy                           0.88       300
#    macro avg       0.72      0.87      0.76       300
# weighted avg       0.93      0.88      0.90       300

# %%
rf_clf = RandomForestClassifier(n_estimators=30, max_depth=3)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       270
#            1       0.95      0.67      0.78        30
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.83      0.88       300
# weighted avg       0.96      0.96      0.96       300

# %%
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       270
#            1       0.96      0.80      0.87        30
#
#     accuracy                           0.98       300
#    macro avg       0.97      0.90      0.93       300
# weighted avg       0.98      0.98      0.98       300

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_res, y_train_res = smt.fit_resample(X_train, y_train)

np.unique(y_train_res, return_counts=True)
# Out:
# (array([0, 1]), array([619, 619], dtype=int64))

# %%
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train_res, y_train_res)
y_pred_xgb = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       270
#            1       0.86      0.83      0.85        30
#
#     accuracy                           0.97       300
#    macro avg       0.92      0.91      0.92       300
# weighted avg       0.97      0.97      0.97       300

# %%
import mlflow

# %%
models = [
    (
        "Logistic Regression", 
        LogisticRegression(max_iter=1000,C=1, solver='liblinear'), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "Random Forest", 
        RandomForestClassifier(n_estimators=30, max_depth=3), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier",
        XGBClassifier(use_label_encoder=False, eval_metric='logloss'), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier With SMOTE",
        XGBClassifier(use_label_encoder=False, eval_metric='logloss'), 
        (X_train_res, y_train_res),
        (X_test, y_test)
    )
]

reports = []

for model_name, model, train_set, test_set in models:
    X_train = train_set[0]
    y_train = train_set[1]
    X_test = test_set[0]
    y_test = test_set[1]
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True)
    reports.append(report)

# %%
import mlflow
import mlflow.xgboost
import mlflow.sklearn
mlflow.set_experiment("Anamoly Detection")
mlflow.set_tracking_uri("http://127.0.0.1:5000")
for i,element in enumerate(models):
    model_name=element[0]
    model=element[1]
    report=reports[i]
    with mlflow.start_run(run_name=model_name):
         
          mlflow.log_param("model",model_name)
          
          mlflow.log_metric('accuracy', report['accuracy'])
          mlflow.log_metric('recall_class_1', report['1']['recall'])
          mlflow.log_metric('recall_class_0', report['0']['recall'])
          mlflow.log_metric('f1_score_macro', report['macro avg']['f1-score'])  

          if isinstance(model, XGBClassifier):
              mlflow.xgboost.log_model(model,name="model")
          else:
              mlflow.sklearn.log_model(model,artifact_path="model")
# Out:
# 2025/11/04 17:10:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/04 17:10:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Logistic Regression at: http://127.0.0.1:5000/#/experiments/961996740831763576/runs/a739fe75b08147869f25b0d1b08684a6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/961996740831763576
# 2025/11/04 17:10:50 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/04 17:11:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest at: http://127.0.0.1:5000/#/experiments/961996740831763576/runs/357f6b0753734e7f865b0671c19932bc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/961996740831763576
# 2025/11/04 17:11:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGBClassifier at: http://127.0.0.1:5000/#/experiments/961996740831763576/runs/8d2b4ebf87c24f279df12321e705ff61
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/961996740831763576
# 2025/11/04 17:11:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGBClassifier With SMOTE at: http://127.0.0.1:5000/#/experiments/961996740831763576/runs/79d8f59f7cb34d9986f6a1558cb15239
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/961996740831763576

# %%
model = 'XGB'
run_id=input('Please type RunID')
model_uri = f'runs:/{run_id}/model'

with mlflow.start_run(run_id=run_id):
    mlflow.register_model(model_uri=model_uri, name=model_name)
# Out:
# Please type RunID 8d2b4ebf87c24f279df12321e705ff61
# Registered model 'XGB' already exists. Creating a new version of this model...
# 2025/11/04 18:11:11 WARNING mlflow.tracking._model_registry.fluent: Run with id 8d2b4ebf87c24f279df12321e705ff61 has no artifacts at artifact path 'model', registering model based on models:/m-b9f8dc62d2b4496ca91cba0a9a92b177 instead
# 2025/11/04 18:11:11 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: XGB, version 1
# 🏃 View run XGBClassifier at: http://127.0.0.1:5000/#/experiments/961996740831763576/runs/8d2b4ebf87c24f279df12321e705ff61
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/961996740831763576
# Created version '1' of model 'XGB'.

# %%
model_version = 1
model_uri = f"models:/{model_name}/{model_version}"

loaded_model = mlflow.xgboost.load_model(model_uri)
y_pred = loaded_model.predict(X_test)
y_pred[:4]
# Out:
# array([0, 0, 0, 0])

# %%
current_model_uri = f"models:/{model_name}@challenger"
production_model_name = "anomaly-detection-prod"

client = mlflow.MlflowClient()
client.copy_model_version(src_model_uri=current_model_uri, dst_name=production_model_name)
# Out:
# Successfully registered model 'anomaly-detection-prod'.
# Copied version '1' of model 'XGB' to version '1' of model 'anomaly-detection-prod'.
# <ModelVersion: aliases=[], creation_timestamp=1762260941723, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1762260941723, metrics=None, model_id=None, name='anomaly-detection-prod', params=None, run_id='8d2b4ebf87c24f279df12321e705ff61', run_link='', source='models:/XGB/1', status='READY', status_message=None, tags={}, user_id='', version='1'>

# %%
model_version = 1
prod_model_uri = f"models:/{production_model_name}@champion"

loaded_model = mlflow.xgboost.load_model(prod_model_uri)
y_pred = loaded_model.predict(X_test)
y_pred[:4]
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[67], line 4
#       1 model_version = 1
#       2 prod_model_uri = f"models:/{production_model_name}@champion"
# ----> 4 loaded_model = mlflow.xgboost.load_model(prod_model_uri)
#       5 y_pred = loaded_model.predict(X_test)
#       6 y_pred[:4]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\xgboost\__init__.py:356, in load_model(model_uri, dst_path)
#     334 def load_model(model_uri, dst_path=None):
#     335     """Load an XGBoost model from a local file or a run.
#     336
#     337     Args:
#    (...)
#     354         models, depending on the saved model class specification.
#     355     """
# --> 356     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     357     flavor_conf = _get_flavor_configuration(local_model_path, FLAVOR_NAME)
#     358     _add_code_from_conf_to_system_path(local_model_path, flavor_conf)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\tracking\artifact_utils.py:117, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info, tracking_uri, registry_uri)
#     107 """
#     108 Args:
#     109     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)
#     114     registry_uri: The registry URI to be used when downloading artifacts.
#     115 """
#     116 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 117 repo = get_artifact_repository(
#     118     artifact_uri=root_uri, tracking_uri=tracking_uri, registry_uri=registry_uri
#     119 )
#     121 try:
#     122     if isinstance(repo, ModelsArtifactRepository):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\store\artifact\artifact_repository_registry.py:147, in get_artifact_repository(artifact_uri, tracking_uri, registry_uri)
#     128 def get_artifact_repository(
#     129     artifact_uri: str, tracking_uri: str | None = None, registry_uri: str | None = None
#     130 ) -> ArtifactRepository:
#     131     """
#     132     Get an artifact repository from the registry based on the scheme of artifact_uri
#     133
#    (...)
#     145         requirements.
#     146     """
# --> 147     return _artifact_repository_registry.get_artifact_repository(
#     148         artifact_uri, tracking_uri, registry_uri
#     149     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\store\artifact\artifact_repository_registry.py:83, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri, tracking_uri, registry_uri)
#      78 if repository is None:
#      79     raise MlflowException(
#      80         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      81         f"Currently registered schemes are: {list(self._registry.keys())}"
#      82     )
# ---> 83 return repository(artifact_uri, tracking_uri=tracking_uri, registry_uri=registry_uri)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\store\artifact\models_artifact_repo.py:83, in ModelsArtifactRepository.__init__(self, artifact_uri, tracking_uri, registry_uri)
#      77     self.model_version = self.repo.model_version
#      78 else:
#      79     (
#      80         self.model_name,
#      81         self.model_version,
#      82         underlying_uri,
# ---> 83     ) = ModelsArtifactRepository._get_model_uri_infos(artifact_uri)
#      84     self.repo = get_artifact_repository(
#      85         underlying_uri, tracking_uri=tracking_uri, registry_uri=registry_uri
#      86     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\store\artifact\models_artifact_repo.py:136, in ModelsArtifactRepository._get_model_uri_infos(uri)
#     132 databricks_profile_uri = (
#     133     get_databricks_profile_uri_from_artifact_uri(uri) or mlflow.get_registry_uri()
#     134 )
#     135 client = MlflowClient(registry_uri=databricks_profile_uri)
# --> 136 name_and_version_or_id = get_model_name_and_version(client, uri)
#     137 if len(name_and_version_or_id) == 1:
#     138     name = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\store\artifact\utils\models.py:150, in get_model_name_and_version(client, models_uri)
#     147     client = client._get_registry_client()
#     149 if model_alias is not None:
# --> 150     mv = client.get_model_version_by_alias(model_name, model_alias)
#     151     return model_name, mv.version
#     152 return model_name, str(_get_latest_model_version(client, model_name, model_stage))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\tracking\_model_registry\client.py:474, in ModelRegistryClient.get_model_version_by_alias(self, name, alias)
#     463 def get_model_version_by_alias(self, name, alias):
#     464     """Get the model version instance by name and alias.
#     465
#     466     Args:
#    (...)
#     472
#     473     """
# --> 474     return self.store.get_model_version_by_alias(name, alias)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\store\model_registry\rest_store.py:506, in RestStore.get_model_version_by_alias(self, name, alias)
#     495 """
#     496 Get the model version instance by name and alias.
#     497
#    (...)
#     503     A single :py:class:`mlflow.entities.model_registry.ModelVersion` object.
#     504 """
#     505 req_body = message_to_json(GetModelVersionByAlias(name=name, alias=alias))
# --> 506 response_proto = self._call_endpoint(GetModelVersionByAlias, req_body)
#     507 return ModelVersion.from_proto(response_proto.model_version)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\store\model_registry\base_rest_store.py:42, in BaseRestStore._call_endpoint(self, api, json_body, call_all_endpoints, extra_headers)
#      40 else:
#      41     endpoint, method = self._get_endpoint_from_method(api)
# ---> 42     return call_endpoint(
#      43         self.get_host_creds(), endpoint, method, json_body, response_proto, extra_headers
#      44     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\rest_utils.py:592, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     589     call_kwargs["json"] = json_body
#     590     response = http_request(**call_kwargs)
# --> 592 response = verify_rest_response(response, endpoint)
#     593 response_to_parse = response.text
#     594 try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\rest_utils.py:311, in verify_rest_response(response, endpoint)
#     309 if response.status_code != 200:
#     310     if _can_parse_as_json_object(response.text):
# --> 311         raise RestException(json.loads(response.text))
#     312     else:
#     313         base_msg = (
#     314             f"API request to endpoint {endpoint} "
#     315             f"failed with error code {response.status_code} != 200"
#     316         )
#
# RestException: INVALID_PARAMETER_VALUE: Registered model alias champion not found.

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\PC'

# %%
pwd
# Out:
# 'C:\\Users\\PC'

# %%
print(os.getcwd())
# Out:
# C:\Users\PC
